# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Looking in indexes: https://pypi.org/simple, https://drake-packages.csail.mit.edu/whl/nightly
# Collecting underactuated==2024.06.22
#   Using cached underactuated-2024.6.22-py3-none-any.whl (986 kB)
# Collecting ipywidgets>7
#   Using cached ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Collecting drake>=1.30.0
#   Downloading drake-1.33.0-cp310-cp310-manylinux_2_35_x86_64.whl (79.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.7/79.7 MB 22.9 MB/s eta 0:00:00
# Collecting pandas>=2.0
#   Using cached pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
# Collecting gradescope-utils>=0.4.0
#   Using cached gradescope_utils-0.5.0-py2.py3-none-any.whl (7.1 kB)
# Collecting timeout-decorator>=0.4.1
#   Using cached timeout-decorator-0.5.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting numpy<2.0.0
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 51.1 MB/s eta 0:00:00
# Collecting scipy>=1.10.0
#   Using cached scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.2 MB)
# Collecting mpld3>=0.5.1
#   Downloading mpld3-0.5.10-py3-none-any.whl (202 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.6/202.6 KB 67.7 MB/s eta 0:00:00
# Collecting pydot>=1.3.0
#   Downloading pydot-3.0.2-py3-none-any.whl (35 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 46.2 MB/s eta 0:00:00
# Collecting PyYAML
#   Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 KB 67.4 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=6.1.0 in /home/jzt/robot_ws/control_env/lib/python3.10/site-packages (from ipywidgets>7->underactuated==2024.06.22->-r ./requirements.txt (line 3)) (8.27.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/jzt/robot_ws/control_env/lib/python3.10/site-packages (from ipywidgets>7->underactuated==2024.06.22->-r ./requirements.txt (line 3)) (5.14.3)
# Requirement already satisfied: comm>=0.1.3 in /home/jzt/robot_ws/control_env/lib/python3.10/site-packages (from ipywidgets>7->underactuated==2024.06.22->-r ./requirements.txt (line 3)) (0.2.2)
# Collecting widgetsnbextension~=4.0.12
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 66.5 MB/s eta 0:00:00
# Collecting jupyterlab-widgets~=3.0.12
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 KB 39.3 MB/s eta 0:00:00
# Collecting jinja2
#   Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 KB 45.8 MB/s eta 0:00:00
# Collecting pytz>=2020.1
#   Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.0/508.0 KB 87.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jzt/robot_ws/control_env/lib/python3.10/site-packages (from pandas>=2.0->underactuated==2024.06.22->-r ./requirements.txt (line 3)) (2.9.0.post0)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 KB 53.9 MB/s eta 0:00:00
# Collecting pyparsing>=3.0.9
#   Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 KB 36.5 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib-inline in /home/jzt/robot_ws/control_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>7->underactuated==2024.06.22->-r ./requirements.txt (line 3)) (0.1.7)
# Requirement already satisfied: jedi>=0.16 in /home/jzt/robot_ws/control_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>7->underactuated==2024.06.22->-r ./requirements.txt (line 3)) (0.19.1)
# Requirement already satisfied: decorator in /home/jzt/robot_ws/control_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>7->underactuated==2024.06.22->-r ./requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: exceptiongroup in /home/jzt/robot_ws/control_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>7->underactuated==2024.06.22->-r ./requirements.txt (line 3)) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /home/jzt/robot_ws/control_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>7->underactuated==2024.06.22->-r ./requirements.txt (line 3)) (4.9.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/jzt/robot_ws/control_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>7->underactuated==2024.06.22->-r ./requirements.txt (line 3)) (3.0.48)
# Requirement already satisfied: stack-data in /home/jzt/robot_ws/control_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>7->underactuated==2024.06.22->-r ./requirements.txt (line 3)) (0.6.3)
# Requirement already satisfied: pygments>=2.4.0 in /home/jzt/robot_ws/control_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>7->underactuated==2024.06.22->-r ./requirements.txt (line 3)) (2.18.0)
# Requirement already satisfied: typing-extensions>=4.6 in /home/jzt/robot_ws/control_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>7->underactuated==2024.06.22->-r ./requirements.txt (line 3)) (4.12.2)
# Requirement already satisfied: six>=1.5 in /home/jzt/robot_ws/control_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=2.0->underactuated==2024.06.22->-r ./requirements.txt (line 3)) (1.16.0)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.54.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 73.9 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.0/322.0 KB 69.5 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.7-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 72.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /home/jzt/robot_ws/control_env/lib/python3.10/site-packages (from matplotlib->drake>=1.30.0->underactuated==2024.06.22->-r ./requirements.txt (line 3)) (24.1)
# Collecting pillow>=8
#   Downloading pillow-10.4.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 69.2 MB/s eta 0:00:00
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/jzt/robot_ws/control_env/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>7->underactuated==2024.06.22->-r ./requirements.txt (line 3)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/jzt/robot_ws/control_env/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>7->underactuated==2024.06.22->-r ./requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/jzt/robot_ws/control_env/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>7->underactuated==2024.06.22->-r ./requirements.txt (line 3)) (0.2.13)
# Requirement already satisfied: asttokens>=2.1.0 in /home/jzt/robot_ws/control_env/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>7->underactuated==2024.06.22->-r ./requirements.txt (line 3)) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in /home/jzt/robot_ws/control_env/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>7->underactuated==2024.06.22->-r ./requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: pure-eval in /home/jzt/robot_ws/control_env/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>7->underactuated==2024.06.22->-r ./requirements.txt (line 3)) (0.2.3)
# Using legacy 'setup.py install' for timeout-decorator, since package 'wheel' is not installed.
# Installing collected packages: timeout-decorator, pytz, gradescope-utils, widgetsnbextension, tzdata, PyYAML, pyparsing, pillow, numpy, MarkupSafe, kiwisolver, jupyterlab-widgets, fonttools, cycler, scipy, pydot, pandas, jinja2, contourpy, matplotlib, mpld3, ipywidgets, drake, underactuated
#   Running setup.py install for timeout-decorator: started
#   Running setup.py install for timeout-decorator: finished with status 'done'
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.1
#     Uninstalling numpy-2.1.1:
#       Successfully uninstalled numpy-2.1.1
# Successfully installed MarkupSafe-2.1.5 PyYAML-6.0.2 contourpy-1.3.0 cycler-0.12.1 drake-1.33.0 fonttools-4.54.1 gradescope-utils-0.5.0 ipywidgets-8.1.5 jinja2-3.1.4 jupyterlab-widgets-3.0.13 kiwisolver-1.4.7 matplotlib-3.9.2 mpld3-0.5.10 numpy-1.26.4 pandas-2.2.3 pillow-10.4.0 pydot-3.0.2 pyparsing-3.1.4 pytz-2024.2 scipy-1.14.1 timeout-decorator-0.5.0 tzdata-2024.2 underactuated-2024.6.22 widgetsnbextension-4.0.13

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=0b814cbb-248e-4cbe-851f-6ad67c55f703' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
